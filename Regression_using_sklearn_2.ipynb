# %% [markdown]
# You have given a housing dataset in data/housing_data.csv file. Split this data into train and test data.
#
# Train a linear regression model using the train data and predict the target values for the test data. Also, check the mean squared error.

# %%
#import packages here
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

# %%
# !ls
# Out:
# housing_data.csv  sample_data

# %%
data = np.loadtxt(open("housing_data.csv","rb"),delimiter=",")
print(data.shape)
# Out:
# (506, 14)

# %%
X = data[:,0:13]
y = data[:,13]
y = y.reshape(-1,1)
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.20, random_state=42)
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (404, 13) (404, 1) (102, 13) (102, 1)

# %%
model = linear_model.LinearRegression(fit_intercept="True")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-19b3f30fddb4> in <module>()
# ----> 1 model = linear_model.LinearRegression(fit_intercept="True")
#
# NameError: name 'linear_model' is not defined

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = model.predict(X_test)

# %%
error = mean_squared_error(y_pred,y_test)

# %%
print(error)
# Out:
# 24.311426929693507
