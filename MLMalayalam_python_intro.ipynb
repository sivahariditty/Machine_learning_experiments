# %% [markdown]
# #Google colab and python basics

# %%
# !ls
# Out:
# sample_data

# %%
# !touch abc

# %%
# !ls
# Out:
# abc  sample_data

# %%
print ('hello world')
# Out:
# hello world

# %%
name = 'redmi note 7 pro'
type(name)
# Out:
# str

# %%
no_of_cams = 1
type(no_of_cams)
# Out:
# int

# %%
ver = 2.3
type(ver)
# Out:
# float

# %%
nos = [1,2,3,4,5,6,7,8,9]
type(nos)
print("first no is",nos[0])
# Out:
# first no is 1

# %%
myphone = {"os":"Android","make":"Redmi","model":"Note 7 Pro"}
type(myphone)
print('my phone is ',myphone["make"])
# Out:
# my phone is  Redmi

# %%
a = 10
if a>5 :
  print('a is greater')
  print('this line is also in if')
else :
  print('a is smaller')
# Out:
# a is greater
# this line is also in if

# %%
for i in range(5):
  print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def my_function():
  print('this is my first function')

# %%
my_function()
# Out:
# this is my first function

# %%
def findsum(a,b,c=0):
  return a+b+c

# %%
print(findsum(10,5,10))
# Out:
# 25

# %% [markdown]
# #Numpy Introduction

# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
b = np.array([[1,2,3],[4,5,6],[8,9,10]])
print(b)
# Out:
# [[ 1  2  3]
#  [ 4  5  6]
#  [ 8  9 10]]

# %%
print(b.shape)
# Out:
# (3, 3)

# %%
print(b[0,:])
# Out:
# [1 2 3]

# %%
print(b[:,1])
# Out:
# [2 5 9]

# %%
print(b[0,0:2])
# Out:
# [1 2]

# %%
print(b.shape)
# Out:
# (3, 3)

# %%
c = np.array([[1,2,3],[4,5,6]])

# %%
print(c.shape)
print(c)
# Out:
# (2, 3)
# [[1 2 3]
#  [4 5 6]]

# %%
d = c.reshape((3,2))
print(d)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
print(d.shape)
# Out:
# (3, 2)

# %%
print(d)
dt = d.transpose()
print("transpose is")
print(dt)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# transpose is
# [[1 3 5]
#  [2 4 6]]

# %%
x = np.array([[1,2],[3,4]])
y = np.array([[1,2,3],[4,5,6]])
print(x.shape,y.shape)
z = np.dot(x,y)
print(z)
# Out:
# (2, 2) (2, 3)
# [[ 9 12 15]
#  [19 26 33]]

# %%
# !cat phones.csv
# Out:
# 1,8500
# 2,7000
# 3,12500
# 4,17500

# %%
data = np.loadtxt(open("phones.csv","rb"),delimiter=",")
print(data[0,1])
# Out:
# 8500.0
