# %% [markdown]
# #Introduction to Python for ML

# %%
print ('hello world')
# Out:
# hello world
# ERROR! Session/line number was not unique in database. History logging moved to new session 59

# %%
a = [1,2,3,4,5]

# %%
print(a[0])
# Out:
# 1

# %%
b = {"name":"sivahari","age":30,"address":"vaikom"}

# %%
print(b["name"])
# Out:
# sivahari
