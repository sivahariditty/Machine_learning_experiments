# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

# %%
X = np.array([[2.2,5.47,6.9,9.4,16.8]])
X = X.reshape([5,1])
X.shape
# Out:
# (5, 1)

# %%
y_actual =  np.array([2.2,16.5,23.8,40,54.9])
y_actual = y_actual.reshape([5,1])
y_actual.shape
# Out:
# (5, 1)

# %%
  plt.scatter(X,y_actual)

# %%
y = y_actual
plt.plot(X,y_actual)

# %%
model = linear_model.LinearRegression(fit_intercept="True")

# %%
model.fit(X,y)
print(model.coef_)
print(model.intercept_)
# Out:
# [[3.62786844]]
# [-2.10163928]

# %%
y_pred = model.predict(X)

# %%
plt.scatter(X,y,color="red")
plt.plot(X,y_pred,color='green')

# %%
deg = 2
scalar = StandardScaler()
polynomial_features = PolynomialFeatures(degree=deg,include_bias="False")
linear = linear_model.LinearRegression(fit_intercept="True")
pipeline = Pipeline([("polynomial",polynomial_features),("scaling",scalar),("linear",linear)])

# %%
pipeline.fit(X,y)
# Out:
# Pipeline(memory=None,
#          steps=[('polynomial',
#                  PolynomialFeatures(degree=2, include_bias='False',
#                                     interaction_only=False, order='C')),
#                 ('scaling',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('linear',
#                  LinearRegression(copy_X=True, fit_intercept='True',
#                                   n_jobs=None, normalize=False))],
#          verbose=False)

# %%
y_pred = pipeline.predict(X)

# %%
print(linear.coef_)
print(linear.intercept_)
# Out:
# [[  0.          33.74528581 -16.36090474]]
# [27.48]

# %%
plt.scatter(X,y,color="red")
plt.plot(X,y_pred,color='green')

# %%
deg = 4
polynomial_features = PolynomialFeatures(degree=deg,include_bias="True")
linear = linear_model.LinearRegression(fit_intercept="True")
pipeline = Pipeline([("polynomial",polynomial_features),("linear",linear)])
pipeline.fit(X,y)
y_pred = pipeline.predict(X)
plt.scatter(X,y,color="red")
plt.plot(X,y_pred,color='green')
print(linear.coef_)
print(linear.intercept_)
# Out:
# [[ 0.00000000e+00  9.57123792e+00 -1.58808771e+00  1.87331286e-01
#   -6.69001350e-03]]
# [-13.00836487]
